# %%
1.import pandas as pd
from sklearn.datasets import load_iris

iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['target'] = iris.target

# %%
2.df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')

# %%
3.column_means = df.mean()
column_means
# Out:
# sepal length (cm)    5.843333
# sepal width (cm)     3.057333
# petal length (cm)    3.758000
# petal width (cm)     1.199333
# target               1.000000
# dtype: float64

# %%
4.df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %%
5.species_means = df.groupby('target')['sepal length (cm)'].mean()
species_means
# Out:
# target
# 0    5.006
# 1    5.936
# 2    6.588
# Name: sepal length (cm), dtype: float64

# %%
6.species_medians = df.groupby('target')['petal width (cm)'].median()
species_medians
# Out:
# target
# 0    0.2
# 1    1.3
# 2    2.0
# Name: petal width (cm), dtype: float64

# %%
7.df.iloc[20:26]
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 20                5.4               3.4                1.7               0.2
# 21                5.1               3.7                1.5               0.4
# 22                4.6               3.6                1.0               0.2
# 23                5.1               3.3                1.7               0.5
# 24                4.8               3.4                1.9               0.2
# 25                5.0               3.0                1.6               0.2
#
#     target
# 20       0
# 21       0
# 22       0
# 23       0
# 24       0
# 25       0
